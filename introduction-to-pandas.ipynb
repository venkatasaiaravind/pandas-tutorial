# %%
import pandas as pd

# %%
series = pd.Series(["bmw","audi","honda"])

# %% [raw]
# series

# %%
series
# Out:
# 0      bmw
# 1     audi
# 2    honda
# dtype: object

# %%
colors = pd.Series(["red","blue","pink"])
colors
# Out:
# 0     red
# 1    blue
# 2    pink
# dtype: object

# %%
#series are 1 dimentional

# %%
#detaframes are 2 dimentional 
car_data = pd.DataFrame({"car_maker": series,"car_color": colors})
car_data
# Out:
#   car_maker car_color
# 0       bmw       red
# 1      audi      blue
# 2     honda      pink

# %%
# importing data
car_sales = pd.read_csv("car-sales.csv")

# %% [raw]
# car_sales

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-car_sales")

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 car_sales["Odometer (KM)"].mean()
#
# NameError: name 'car_sales' is not defined

# %%
len(car_sales)

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [raw]
# car_sales

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(car_sales["Doors"], car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales.groupby(["Make"]).mean("Price")
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Price"]).mean("Price")
# Out:
#             Odometer (KM)  Doors
# Price
# $22,000.00        11179.0    5.0
# $3,500.00        213095.0    4.0
# $4,000.00        150043.0    4.0
# $4,500.00         99213.0    4.0
# $5,000.00         87899.0    4.0
# $6,250.00         60000.0    4.0
# $7,000.00         43643.5    3.5
# $7,500.00         45698.0    4.0
# $9,700.00         31600.0    4.0

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales[["Odometer (KM)" ,"Doors"]].plot()
plt.show()

# %%
car_sales[["Odometer (KM)" ,"Doors"]].mean().plot()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

car_sales[["Odometer (KM)", "Doors"]].plot()
plt.show()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Odometer (KM)"].hist()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"].dtype
# Out:
# dtype('O')

# %%
car_sales["Odometer (KM)"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Colour"].dtype
# Out:
# dtype('O')

# %% [raw]
# car_sales["Doors"].dtype

# %%
car_sales["Doors"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #Manipulating data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales["Colour"] = car_sales["Colour"].str.upper()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  WHITE         150043      4   $4,000.00
# 1   honda    RED          87899      4   $5,000.00
# 2  toyota   BLUE          32549      3   $7,000.00
# 3     bmw  BLACK          11179      5  $22,000.00
# 4  nissan  WHITE         213095      4   $3,500.00
# 5  toyota  GREEN          99213      4   $4,500.00
# 6   honda   BLUE          45698      4   $7,500.00
# 7   honda   BLUE          54738      4   $7,000.00
# 8  toyota  WHITE          60000      4   $6,250.00
# 9  nissan  WHITE          31600      4   $9,700.00

# %%
seats_column = pd.Series([5,5,5,5,5,5])

# %%
car_sales["seats"]= seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  toyota  WHITE         150043      4   $4,000.00    5.0
# 1   honda    RED          87899      4   $5,000.00    5.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0
# 3     bmw  BLACK          11179      5  $22,000.00    5.0
# 4  nissan  WHITE         213095      4   $3,500.00    5.0
# 5  toyota  GREEN          99213      4   $4,500.00    5.0
# 6   honda   BLUE          45698      4   $7,500.00    NaN
# 7   honda   BLUE          54738      4   $7,000.00    NaN
# 8  toyota  WHITE          60000      4   $6,250.00    NaN
# 9  nissan  WHITE          31600      4   $9,700.00    NaN

# %%
car_sales["seats"].fillna(5)
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: seats, dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  toyota  WHITE         150043      4   $4,000.00    5.0
# 1   honda    RED          87899      4   $5,000.00    5.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0
# 3     bmw  BLACK          11179      5  $22,000.00    5.0
# 4  nissan  WHITE         213095      4   $3,500.00    5.0
# 5  toyota  GREEN          99213      4   $4,500.00    5.0
# 6   honda   BLUE          45698      4   $7,500.00    NaN
# 7   honda   BLUE          54738      4   $7,000.00    NaN
# 8  toyota  WHITE          60000      4   $6,250.00    NaN
# 9  nissan  WHITE          31600      4   $9,700.00    NaN

# %%
car_sales["seats"]=car_sales["seats"].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  toyota  WHITE         150043      4   $4,000.00    5.0
# 1   honda    RED          87899      4   $5,000.00    5.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0
# 3     bmw  BLACK          11179      5  $22,000.00    5.0
# 4  nissan  WHITE         213095      4   $3,500.00    5.0
# 5  toyota  GREEN          99213      4   $4,500.00    5.0
# 6   honda   BLUE          45698      4   $7,500.00    5.0
# 7   honda   BLUE          54738      4   $7,000.00    5.0
# 8  toyota  WHITE          60000      4   $6,250.00    5.0
# 9  nissan  WHITE          31600      4   $9,700.00    5.0

# %% [markdown]
# #column for python list

# %%
fuel_economy=[9.8,45,3.4,65.4,4.5,34.3,34,7,4.2,23]

# %%
car_sales["fuel_per_10km"]=fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel_per_10km
# 0  toyota  WHITE         150043      4   $4,000.00    5.0            9.8
# 1   honda    RED          87899      4   $5,000.00    5.0           45.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0            3.4
# 3     bmw  BLACK          11179      5  $22,000.00    5.0           65.4
# 4  nissan  WHITE         213095      4   $3,500.00    5.0            4.5
# 5  toyota  GREEN          99213      4   $4,500.00    5.0           34.3
# 6   honda   BLUE          45698      4   $7,500.00    5.0           34.0
# 7   honda   BLUE          54738      4   $7,000.00    5.0            7.0
# 8  toyota  WHITE          60000      4   $6,250.00    5.0            4.2
# 9  nissan  WHITE          31600      4   $9,700.00    5.0           23.0

# %%
car_sales["total fuel used"]=car_sales["Odometer (KM)"]*car_sales["fuel_per_10km"]/10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel_per_10km  \
# 0  toyota  WHITE         150043      4   $4,000.00    5.0            9.8
# 1   honda    RED          87899      4   $5,000.00    5.0           45.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0            3.4
# 3     bmw  BLACK          11179      5  $22,000.00    5.0           65.4
# 4  nissan  WHITE         213095      4   $3,500.00    5.0            4.5
# 5  toyota  GREEN          99213      4   $4,500.00    5.0           34.3
# 6   honda   BLUE          45698      4   $7,500.00    5.0           34.0
# 7   honda   BLUE          54738      4   $7,000.00    5.0            7.0
# 8  toyota  WHITE          60000      4   $6,250.00    5.0            4.2
# 9  nissan  WHITE          31600      4   $9,700.00    5.0           23.0
#
#    total fuel used
# 0        147042.14
# 1        395545.50
# 2         11066.66
# 3         73110.66
# 4         95892.75
# 5        340300.59
# 6        155373.20
# ...

# %%
car_sales["total number of weels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel_per_10km  \
# 0  toyota  WHITE         150043      4   $4,000.00    5.0            9.8
# 1   honda    RED          87899      4   $5,000.00    5.0           45.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0            3.4
# 3     bmw  BLACK          11179      5  $22,000.00    5.0           65.4
# 4  nissan  WHITE         213095      4   $3,500.00    5.0            4.5
# 5  toyota  GREEN          99213      4   $4,500.00    5.0           34.3
# 6   honda   BLUE          45698      4   $7,500.00    5.0           34.0
# 7   honda   BLUE          54738      4   $7,000.00    5.0            7.0
# 8  toyota  WHITE          60000      4   $6,250.00    5.0            4.2
# 9  nissan  WHITE          31600      4   $9,700.00    5.0           23.0
#
#    total fuel used  total number of weels
# 0        147042.14                      4
# 1        395545.50                      4
# ...

# %%
car_sales["passed road saftey"]= True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel_per_10km  \
# 0  toyota  WHITE         150043      4   $4,000.00    5.0            9.8
# 1   honda    RED          87899      4   $5,000.00    5.0           45.0
# 2  toyota   BLUE          32549      3   $7,000.00    5.0            3.4
# 3     bmw  BLACK          11179      5  $22,000.00    5.0           65.4
# 4  nissan  WHITE         213095      4   $3,500.00    5.0            4.5
# 5  toyota  GREEN          99213      4   $4,500.00    5.0           34.3
# 6   honda   BLUE          45698      4   $7,500.00    5.0           34.0
# 7   honda   BLUE          54738      4   $7,000.00    5.0            7.0
# 8  toyota  WHITE          60000      4   $6,250.00    5.0            4.2
# 9  nissan  WHITE          31600      4   $9,700.00    5.0           23.0
#
#    total fuel used  total number of weels  passed road saftey
# 0        147042.14                      4                True
# ...
